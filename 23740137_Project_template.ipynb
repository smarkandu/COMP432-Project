# %% [markdown]
# # **Circuit Component Image Identifier**
# By Steven Markandu (#23740137)

# %% [markdown]
# ## **Abstract**
# The goal of this project was to train a model that takes hand drawn circuit component images as input and is able to properly classify them using the label given to us via the data set.  The data set was obtained via Kaggle, and contains the necessary images which can be used for both training the model and then finally testing it.  CNNs was used in implementing this.
#
# The main challenges include having enough data to sufficiently test/train my model.  A huge challenge will be in researching a sufficient machine learning model(s) different from CNN in order to accomplish the same task.  And finally, fine-tuning our model in order to achieve the best performance we’re able to achieve.
#
# The performance metrics include:*italicized text*
#
# *   Accuracy
# *   Error
# *   Loss per epoch (using CrossEntropyLoss)

# %% [markdown]
# ## **1.0 Introduction**
#
# Given a hand drawn circuit component diagram, the model should be able to classify what kind of circuit component this is. This is crucial, as every person has their own way of drawing each component. Since a circuit component is valid in any orientation (unlike alphanumeric symbols for example), the model needs to be able to recognize a given component regardless of orientation.
#
# Some similar problems include the following:
#
# * Lab Week 5 - Convolutional Neural Networks
# * Another CNN example (this one involving shapes)
# * https://www.kaggle.com/datasets/reevald/geometric-shapes-mathematics

# %% [markdown]
# ## **2.0 Methodology**
#
# ##2.1 Preprocessing
#
# ##2.2 Model Aspects

# %% [markdown]
# ## **3.0 Experimental Setup**
# # 3.1 Hyperparameter Tuning

# %%
# !python ./src/train.py --lr=0.001 --epochs=3 --batchsize=64 --neurons=20 --eval='True'
# Out:
# python3: can't open file '/content/./src/train.py': [Errno 2] No such file or directory

# %% [markdown]
# ## **4.0 Experimental Results**
# Describe here the main experimental results. Critically discuss them. Compare them with results available in the literature (if applicable).
#
# In this section, you can add **text** and **figures**, **tables**, **plots**, and code. Make sure the code is runnable and replicable.

# %% [markdown]
# ## **5.0 Conclusions**
#
# Summarize what you could and could not conclude based on your experiments.
# In this section, you can add **text**.

# %% [markdown]
# ## **6.0 References**
# You can add here the citations of books, websites, or academic papers, etc.
